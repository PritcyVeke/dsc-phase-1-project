# %% [markdown]
# <a href="https://colab.research.google.com/github/PritcyVeke/dsc-phase-1-project/blob/master/Copy_of_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Movie_gross=pd.read_csv("bom.movie_gross.csv.gz")
Movie_gross.head(2)
# Out:
#                         title studio  domestic_gross foreign_gross  year
# 0                 Toy Story 3     BV     415000000.0     652000000  2010
# 1  Alice in Wonderland (2010)     BV     334200000.0     691300000  2010

# %%
Movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
 Movie_gross['foreign_gross'] =  Movie_gross['foreign_gross'].str.replace(',', '')

# %%
# Changing data type
Movie_gross['foreign_gross'] = Movie_gross['foreign_gross'].astype(float)

# %%
Movie_gross.dropna(subset=['foreign_gross'], inplace=True)

# %%
Movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2032 entries, 0 to 3353
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2032 non-null   object
#  1   studio          2028 non-null   object
#  2   domestic_gross  2004 non-null   float64
#  3   foreign_gross   2032 non-null   float64
#  4   year            2032 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 95.2+ KB

# %%
#mising points for first 10 columns
missingvalue =Movie_gross.isnull() .sum()
missingvalue[0:10]
# Out:
# title              0
# studio             4
# domestic_gross    28
# foreign_gross      0
# year               0
# dtype: int64

# %%
import numpy as np

# %%
#total number of cells in data
total_cells = np.product(Movie_gross.shape)
print(total_cells)
# Out:
# 10185

# %%
#total missing cells
total_missing = missingvalue.sum()
print(total_missing)
# Out:
# 32

# %%
#percrnt of data missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.31418753068237604

# %%
#droping missing values
Movie_gross.dropna()
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year
# 0        415000000.0    652000000.0  2010
# 1        334200000.0    691300000.0  2010
# 2        296000000.0    664300000.0  2010
# 3        292600000.0    535700000.0  2010
# 4        238700000.0    513900000.0  2010
# ...              ...            ...   ...
# 3275          1400.0      1500000.0  2018
# 3286        725000.0       229000.0  2018
# 3309         10000.0       256000.0  2018
# 3342         93200.0         5200.0  2018
# 3353         43200.0        30000.0  2018
#
# [2007 rows x 5 columns]

# %%
Movie_gross.shape
# Out:
# (2037, 5)

# %%
#descriptive analysis
Movie_gross.describe()
# Out:
#        domestic_gross  foreign_gross         year
# count    2.009000e+03   2.037000e+03  2037.000000
# mean     4.697311e+07   7.487281e+07  2013.492882
# std      8.159966e+07   1.374106e+08     2.592412
# min      4.000000e+02   6.000000e+02  2010.000000
# 25%      6.650000e+05   3.700000e+06  2011.000000
# 50%      1.650000e+07   1.870000e+07  2013.000000
# 75%      5.600000e+07   7.490000e+07  2016.000000
# max      9.367000e+08   9.605000e+08  2018.000000

# %%
#correlation between
correlation = Movie_gross['foreign_gross'].corr(Movie_gross['domestic_gross'])
print(correlation)
# Out:
# 0.7679909931978675

# %%
import matplotlib.pyplot as plt

# %%
# A scatter plot to show correlation
x = Movie_gross['domestic_gross']
y = Movie_gross['foreign_gross']


plt.figure(figsize=(8, 6))
plt.scatter(x, y, alpha=0.5)
plt.title('Domestic Gross vs. Foreign Gross')
plt.xlabel('domestic_gross')
plt.ylabel('foreign_gross')


plt.show()

# %%
# Top grossing studio
studioDomestic_gross = Movie_gross.groupby('studio')['domestic_gross'].sum()

# Sort the studios by total gross in descending order and select the top 5
top_5_studios = studioDomestic_gross.sort_values(ascending=False).head(5)

print(top_5_studios)
# Out:
# studio
# BV      1.839653e+10
# Uni.    1.289204e+10
# WB      1.212360e+10
# Fox     1.092450e+10
# Sony    8.459479e+09
# Name: domestic_gross, dtype: float64

# %%
# Top grossing studio
studioforeign_gross = Movie_gross.groupby('studio')['foreign_gross'].sum()

# Sort the studios by total gross in descending order and select the top 5
top_5_studios = studioforeign_gross.sort_values(ascending=False).head(5)

print(top_5_studios)
# Out:
# studio
# BV      2.579385e+10
# Fox     2.005587e+10
# WB      1.866790e+10
# Uni.    1.685477e+10
# Sony    1.394535e+10
# Name: foreign_gross, dtype: float64

# %%
Movieinfo=pd.read_csv("movie_info.csv")
Movieinfo.head(2)
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One

# %%
Movieinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
#libraries for treemap
pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
import squarify

# %%
#ploting studio against domestic gross

squarify.plot(sizes=Movie_gross['domestic_gross'], label=Movie_gross['studio'], alpha=.8 )
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-63-1f9224592dde> in <cell line: 3>()
#       1 #ploting studio against domestic gross
#       2
# ----> 3 squarify.plot(sizes=Movie_gross['domestic_gross'], label=Movie_gross['studio'], alpha=.8 )
#       4 plt.axis('off')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/squarify/__init__.py in plot(sizes, norm_x, norm_y, color, label, value, ax, pad, bar_kwargs, text_kwargs, **kwargs)
#     244         rects = padded_squarify(normed, 0, 0, norm_x, norm_y)
#     245     else:
# --> 246         rects = squarify(normed, 0, 0, norm_x, norm_y)
#     247
#     248     x = [rect["x"] for rect in rects]
#
# /usr/local/lib/python3.10/dist-packages/squarify/__init__.py in squarify(sizes, x, y, dx, dy)
#     134
#     135     (leftover_x, leftover_y, leftover_dx, leftover_dy) = leftover(current, x, y, dx, dy)
# --> 136     return layout(current, x, y, dx, dy) + squarify(
#     137         remaining, leftover_x, leftover_y, leftover_dx, leftover_dy
#     138     )
#
# ... last 1 frames repeated, from the frame below ...
#
# /usr/local/lib/python3.10/dist-packages/squarify/__init__.py in squarify(sizes, x, y, dx, dy)
#     134
#     135     (leftover_x, leftover_y, leftover_dx, leftover_dy) = leftover(current, x, y, dx, dy)
# --> 136     return layout(current, x, y, dx, dy) + squarify(
#     137         remaining, leftover_x, leftover_y, leftover_dx, leftover_dy
#     138     )
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
title_rating=pd.read_csv("imdb.title.ratings.csv.gz")
title_rating.head(2)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559

# %%
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One

# %%
title_Crew=pd.read_csv("imdb.title.crew.csv.gz")
title_Crew.head(2)
# Out:
#       tconst  directors              writers
# 0  tt0285252  nm0899854            nm0899854
# 1  tt0438973        NaN  nm0175726,nm1802864

# %%
Movie=pd.read_csv("tmdb.movies.csv.gz")
# Out:
# <bound method DataFrame.info of                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]>

# %%
Movie_budgets=pd.read_csv("tn.movie_budgets.csv.gz")
Movie_budgets.head(2)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
